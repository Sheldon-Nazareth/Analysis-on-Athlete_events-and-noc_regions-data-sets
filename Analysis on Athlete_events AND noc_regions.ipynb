# %%
#We in this project will use a dataset that I came across which seemed interesting to me. 
#Athlete_events  and noc_regions
#Some random questions to analyze the data after EDA and customization
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Read original data se tin to notebook
data = pd.read_csv('athlete_events.csv', index_col=0)

# %%
data
# Out:
#                             Name Sex   Age  Height  Weight            Team  \
# ID
# 1                      A Dijiang   M  24.0   180.0    80.0           China
# 2                       A Lamusi   M  23.0   170.0    60.0           China
# 3            Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 4           Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 5       Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# ...                          ...  ..   ...     ...     ...             ...
# 135569                Andrzej ya   M  29.0   179.0    89.0        Poland-1
# 135570                  Piotr ya   M  27.0   176.0    59.0          Poland
# 135570                  Piotr ya   M  27.0   176.0    59.0          Poland
# 135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0          Poland
# 135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0          Poland
#
# ...

# %%
#ID - Unique number for each athlete
#Name - Athlete's name 
#Sex - M or F
#Age - Integer
#Height - In centimeters
#Weight - In kilograms
#Team - Team name
#NOC - National Olympic Committee 3-letter code
#Games - Year and season
#Year - Integer
#Season - Summer or Winter
#City - Host city
#Sport - Sport
#Event - Event
#Medal - Gold, Silver, Bronze, or NA
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 271116 entries, 1 to 135571
# Data columns (total 14 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Name    271116 non-null  object
#  1   Sex     271116 non-null  object
#  2   Age     261642 non-null  float64
#  3   Height  210945 non-null  float64
#  4   Weight  208241 non-null  float64
#  5   Team    271116 non-null  object
#  6   NOC     271116 non-null  object
#  7   Games   271116 non-null  object
#  8   Year    271116 non-null  int64
#  9   Season  271116 non-null  object
#  10  City    271116 non-null  object
#  11  Sport   271116 non-null  object
#  12  Event   271116 non-null  object
#  13  Medal   39783 non-null   object
# dtypes: float64(3), int64(1), object(10)
# memory usage: 31.0+ MB

# %%
#read noc file in to notebook
data_noc = pd.read_csv('noc_regions.csv', index_col=0)

# %%
data_noc
# Out:
#           region                 notes
# NOC
# AFG  Afghanistan                   NaN
# AHO      Curacao  Netherlands Antilles
# ALB      Albania                   NaN
# ALG      Algeria                   NaN
# AND      Andorra                   NaN
# ..           ...                   ...
# YEM        Yemen                   NaN
# YMD        Yemen           South Yemen
# YUG       Serbia            Yugoslavia
# ZAM       Zambia                   NaN
# ZIM     Zimbabwe                   NaN
#
# [230 rows x 2 columns]

# %%
data
# Out:
#                             Name Sex   Age  Height  Weight            Team  \
# ID
# 1                      A Dijiang   M  24.0   180.0    80.0           China
# 2                       A Lamusi   M  23.0   170.0    60.0           China
# 3            Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 4           Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 5       Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# ...                          ...  ..   ...     ...     ...             ...
# 135569                Andrzej ya   M  29.0   179.0    89.0        Poland-1
# 135570                  Piotr ya   M  27.0   176.0    59.0          Poland
# 135570                  Piotr ya   M  27.0   176.0    59.0          Poland
# 135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0          Poland
# 135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0          Poland
#
# ...

# %%
#replacing NaN with No in the Medal column
df['Medal'].fillna('No', inplace=True)

# %%
data
# Out:
#                             Name Sex   Age  Height  Weight            Team  \
# ID
# 1                      A Dijiang   M  24.0   180.0    80.0           China
# 2                       A Lamusi   M  23.0   170.0    60.0           China
# 3            Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 4           Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 5       Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# ...                          ...  ..   ...     ...     ...             ...
# 135569                Andrzej ya   M  29.0   179.0    89.0        Poland-1
# 135570                  Piotr ya   M  27.0   176.0    59.0          Poland
# 135570                  Piotr ya   M  27.0   176.0    59.0          Poland
# 135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0          Poland
# 135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0          Poland
#
# ...

# %%
#removing all the missing values in age, heightand weight directly using the dropna() function naming it as __refined_data___
refined_data = data.dropna()

# %%
refined_data
# Out:
#                             Name Sex   Age  Height  Weight         Team  NOC  \
# ID
# 1                      A Dijiang   M  24.0   180.0    80.0        China  CHN
# 2                       A Lamusi   M  23.0   170.0    60.0        China  CHN
# 5       Christine Jacoba Aaftink   F  21.0   185.0    82.0  Netherlands  NED
# 5       Christine Jacoba Aaftink   F  21.0   185.0    82.0  Netherlands  NED
# 5       Christine Jacoba Aaftink   F  25.0   185.0    82.0  Netherlands  NED
# ...                          ...  ..   ...     ...     ...          ...  ...
# 135569                Andrzej ya   M  29.0   179.0    89.0     Poland-1  POL
# 135570                  Piotr ya   M  27.0   176.0    59.0       Poland  POL
# 135570                  Piotr ya   M  27.0   176.0    59.0       Poland  POL
# 135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0       Poland  POL
# 135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0       Poland  POL
#
# ...

# %%
refined_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 206165 entries, 1 to 135571
# Data columns (total 14 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Name    206165 non-null  object
#  1   Sex     206165 non-null  object
#  2   Age     206165 non-null  float64
#  3   Height  206165 non-null  float64
#  4   Weight  206165 non-null  float64
#  5   Team    206165 non-null  object
#  6   NOC     206165 non-null  object
#  7   Games   206165 non-null  object
#  8   Year    206165 non-null  int64
#  9   Season  206165 non-null  object
#  10  City    206165 non-null  object
#  11  Sport   206165 non-null  object
#  12  Event   206165 non-null  object
#  13  Medal   206165 non-null  object
# dtypes: float64(3), int64(1), object(10)
# memory usage: 23.6+ MB

# %%
#remove the repeated values using duplicate function
refined_data.duplicated().any()
# Out:
# True

# %%
refined_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 206165 entries, 1 to 135571
# Data columns (total 14 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Name    206165 non-null  object
#  1   Sex     206165 non-null  object
#  2   Age     206165 non-null  float64
#  3   Height  206165 non-null  float64
#  4   Weight  206165 non-null  float64
#  5   Team    206165 non-null  object
#  6   NOC     206165 non-null  object
#  7   Games   206165 non-null  object
#  8   Year    206165 non-null  int64
#  9   Season  206165 non-null  object
#  10  City    206165 non-null  object
#  11  Sport   206165 non-null  object
#  12  Event   206165 non-null  object
#  13  Medal   206165 non-null  object
# dtypes: float64(3), int64(1), object(10)
# memory usage: 23.6+ MB

# %%
#but on careful analysis there are several combinations although the name is repeted several times these players have attempted 
# to re-enter the competition and participate in multiple sports throught the cycle.

# %%
refined_data.shape
# Out:
# (206165, 14)

# %%
#QUESTION 1: Which country has the most Gold medalists? 
#(Hint Filter by Gold Then Summarize by Country)

#QUESTION 2: Do Female Atheletes win more Medals than their Male Counterparts?
#(Hint Exlude NA from Medals then Summarize by Gender)

#QUESTION 3: How many of the Medals have been won by Pakistan? 
#Summarize Pakistan's Medals by Medal Type 
#(Hint Filter By Pakistan then Take Count of Non-NA Medals, 
#to answer second part Filter the Original Data for Pakistan and Then Summarize by Medal type)

# %%
###############################################################################################################################
# Answer 1 
refined_data['Medal'].unique()
# Out:
# array(['No', 'Bronze', 'Gold', 'Silver'], dtype=object)

# %%
Medal_counts = refined_data['Medal'].value_counts()
Medal_counts
# Out:
# No        175984
# Gold       10167
# Bronze     10148
# Silver      9866
# Name: Medal, dtype: int64

# %%
#using a groupby function on team we can count the number of Gold medals and sort them for ease. 
Gold_medal_data = refined_data[refined_data['Medal'] == 'Gold'].groupby('Team')['Medal'].count().sort_values(ascending=False)
Gold_medal_data
# Out:
# Team
# United States    2075
# Soviet Union      961
# Germany           508
# East Germany      368
# Russia            356
#                  ...
# Tajikistan          1
# Satchmo             1
# Cote d'Ivoire       1
# Jest                1
# Jordan              1
# Name: Medal, Length: 157, dtype: int64

# %%
import matplotlib.pyplot as plt
Gold_medal_data_plot = Gold_medal_data.head(3)
Gold_medal_data_plot
# Out:
# Team
# United States    2075
# Soviet Union      961
# Germany           508
# Name: Medal, dtype: int64

# %%
fig = plt.bar(x=Gold_medal_data_plot.index, height=Gold_medal_data_plot.values)
# adding supplementary formatting 
plt.title('Gold Medalist Countries')
plt.xlabel('Country')
plt.ylabel('Number of Gold Medals Won')
plt.show()
plt.rcParams['figure.figsize'] = [15, 4]

# %%
# We can see the top 3 countries with the maximum number of Gold medals won during the olympics USA leads by a landslide

# %%
#############################################################################################################################
#QUESTION 2: Do Female Atheletes win more Medals than their Male Counterparts?
# Answer 2:

# %%
refined_data
# Out:
#                             Name Sex   Age  Height  Weight         Team  NOC  \
# ID
# 1                      A Dijiang   M  24.0   180.0    80.0        China  CHN
# 2                       A Lamusi   M  23.0   170.0    60.0        China  CHN
# 5       Christine Jacoba Aaftink   F  21.0   185.0    82.0  Netherlands  NED
# 5       Christine Jacoba Aaftink   F  21.0   185.0    82.0  Netherlands  NED
# 5       Christine Jacoba Aaftink   F  25.0   185.0    82.0  Netherlands  NED
# ...                          ...  ..   ...     ...     ...          ...  ...
# 135569                Andrzej ya   M  29.0   179.0    89.0     Poland-1  POL
# 135570                  Piotr ya   M  27.0   176.0    59.0       Poland  POL
# 135570                  Piotr ya   M  27.0   176.0    59.0       Poland  POL
# 135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0       Poland  POL
# 135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0       Poland  POL
#
# ...

# %%
refined_data['Sex'].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
# For **clarity** these are the total number of male and female candidates segregated on the basis of their gender.
Gender_counts = refined_data['Sex'].value_counts()
Gender_counts
# Out:
# M    139454
# F     66711
# Name: Sex, dtype: int64

# %%
# Here the same group data is segregated on the basis of candidates recievng a medal.
Gender_counts = refined_data[refined_data['Medal'] != 'No'].groupby('Sex')['Medal'].count().sort_values(ascending=False)
Gender_counts
# Out:
# Sex
# M    19831
# F    10350
# Name: Medal, dtype: int64

# %%
fig = plt.pie(Gender_counts, labels=Gender_counts.index, autopct='%.2f')

# %%
# The obtained data indicates that Male Athletes have won more medals than female atheles during the olympic games.

# %%
##############################################################################################################################
#QUESTION 3: How many of the Medals have been won by Pakistan?

# %%
refined_data
# Out:
#                             Name Sex   Age  Height  Weight         Team  NOC  \
# ID
# 1                      A Dijiang   M  24.0   180.0    80.0        China  CHN
# 2                       A Lamusi   M  23.0   170.0    60.0        China  CHN
# 5       Christine Jacoba Aaftink   F  21.0   185.0    82.0  Netherlands  NED
# 5       Christine Jacoba Aaftink   F  21.0   185.0    82.0  Netherlands  NED
# 5       Christine Jacoba Aaftink   F  25.0   185.0    82.0  Netherlands  NED
# ...                          ...  ..   ...     ...     ...          ...  ...
# 135569                Andrzej ya   M  29.0   179.0    89.0     Poland-1  POL
# 135570                  Piotr ya   M  27.0   176.0    59.0       Poland  POL
# 135570                  Piotr ya   M  27.0   176.0    59.0       Poland  POL
# 135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0       Poland  POL
# 135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0       Poland  POL
#
# ...

# %%
#search for Pakistan
refined_data[refined_data['Team'].astype(str).str.contains('Pakistan')]
# Out:
#                    Name Sex   Age  Height  Weight      Team  NOC        Games  \
# ID
# 111        Aqarab Abbas   M  22.0   190.0    88.0  Pakistan  PAK  1996 Summer
# 115        Ghulam Abbas   M  24.0   181.0    74.0  Pakistan  PAK  1992 Summer
# 121      Muhammad Abbas   M  23.0   168.0    55.0  Pakistan  PAK  2010 Winter
# 123        Sohail Abbas   M  25.0   178.0    80.0  Pakistan  PAK  2000 Summer
# 123        Sohail Abbas   M  29.0   178.0    80.0  Pakistan  PAK  2004 Summer
# ...                 ...  ..   ...     ...     ...       ...  ...          ...
# 133849      Tahir Zaman   M  23.0   170.0    65.0  Pakistan  PAK  1992 Summer
# 133849      Tahir Zaman   M  27.0   170.0    65.0  Pakistan  PAK  1996 Summer
# 134907        Qamar Zia   M  22.0   168.0    61.0  Pakistan  PAK  1976 Summer
# 134908        Qasim Zia   M  22.0   174.0    71.0  Pakistan  PAK  1984 Summer
# 135329  Muhammad Zubair   M  19.0   167.0    54.0  Pakistan  PAK  2008 Summer
#
# ...

# %%
#using astype we search for pakistan in the  team column and set a new table
Pakistani_participants = refined_data[refined_data['Team'].astype(str).str.contains('Pakistan')]
Pakistani_participants
# Out:
#                    Name Sex   Age  Height  Weight      Team  NOC        Games  \
# ID
# 111        Aqarab Abbas   M  22.0   190.0    88.0  Pakistan  PAK  1996 Summer
# 115        Ghulam Abbas   M  24.0   181.0    74.0  Pakistan  PAK  1992 Summer
# 121      Muhammad Abbas   M  23.0   168.0    55.0  Pakistan  PAK  2010 Winter
# 123        Sohail Abbas   M  25.0   178.0    80.0  Pakistan  PAK  2000 Summer
# 123        Sohail Abbas   M  29.0   178.0    80.0  Pakistan  PAK  2004 Summer
# ...                 ...  ..   ...     ...     ...       ...  ...          ...
# 133849      Tahir Zaman   M  23.0   170.0    65.0  Pakistan  PAK  1992 Summer
# 133849      Tahir Zaman   M  27.0   170.0    65.0  Pakistan  PAK  1996 Summer
# 134907        Qamar Zia   M  22.0   168.0    61.0  Pakistan  PAK  1976 Summer
# 134908        Qasim Zia   M  22.0   174.0    71.0  Pakistan  PAK  1984 Summer
# 135329  Muhammad Zubair   M  19.0   167.0    54.0  Pakistan  PAK  2008 Summer
#
# ...

# %%
# This gives you the total participants who have recieved either Gold, Silver or Bronze medals.
Pak_medal_counts = Pakistani_participants[Pakistani_participants['Medal'] != 'No'].groupby('Team')['Medal'].count().sort_values(ascending=False)
Pak_medal_counts


#########################################################################################
######### %%% 107 participants out of all participationg Pakistanis won a medal %%##############
#########################################################################################
# Out:
# Team
# Pakistan    107
# Name: Medal, dtype: int64

# %%
# For visual representation we can count individual medals in the new table and sort them on a bar graph removing the 
# non-applicable participants.
Pak_medal_counts = Pakistani_participants['Medal'].value_counts().drop('No')
Pak_medal_counts
# Out:
# Gold      42
# Silver    41
# Bronze    24
# Name: Medal, dtype: int64

# %%
#plotting the given values for reference
fig = plt.bar(x=Pak_medal_counts.index, height=Pak_medal_counts.values)
# adding supplementary formatting 
plt.title('Medals Recieved by PAkistanis')
plt.xlabel('Medal Type')
plt.ylabel('Number of Medls Won')
plt.show()
plt.rcParams['figure.figsize'] = [12, 8]

# %%
##############################################################################################################################
#Q4: What is the Average age of participants from different teams  under 22  participating in the Olympics.

# %%
average_age = refined_data.groupby('NOC')['Age'].mean().sort_values().head(12)
average_age
# Out:
# NOC
# MHL    19.461538
# UAR    20.000000
# YEM    20.400000
# MDV    20.571429
# NFL    21.000000
# LAO    21.470588
# TUV    21.500000
# COM    21.600000
# KIR    21.636364
# SAA    21.666667
# SUR    21.750000
# BRU    21.888889
# Name: Age, dtype: float64

# %%
#plotting the given values for reference
fig = plt.bar(x=average_age.index, height=average_age.values)
# adding supplementary formatting 
plt.title('Teams with the youngest participants ')
plt.xlabel('Teams')
plt.ylabel('Participant Age')
plt.show()
plt.rcParams['figure.figsize'] = [30, 10]

# %%
#############################################################################################################################3
#Q5: Which season has the larer nube rof participants
#Ans:

# %%
refined_data
# Out:
#                             Name Sex   Age  Height  Weight         Team  NOC  \
# ID
# 1                      A Dijiang   M  24.0   180.0    80.0        China  CHN
# 2                       A Lamusi   M  23.0   170.0    60.0        China  CHN
# 5       Christine Jacoba Aaftink   F  21.0   185.0    82.0  Netherlands  NED
# 5       Christine Jacoba Aaftink   F  21.0   185.0    82.0  Netherlands  NED
# 5       Christine Jacoba Aaftink   F  25.0   185.0    82.0  Netherlands  NED
# ...                          ...  ..   ...     ...     ...          ...  ...
# 135569                Andrzej ya   M  29.0   179.0    89.0     Poland-1  POL
# 135570                  Piotr ya   M  27.0   176.0    59.0       Poland  POL
# 135570                  Piotr ya   M  27.0   176.0    59.0       Poland  POL
# 135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0       Poland  POL
# 135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0       Poland  POL
#
# ...

# %%
refined_data['Season'].unique()
# Out:
# array(['Summer', 'Winter'], dtype=object)

# %%
Season_counts = refined_data['Season'].value_counts()
Season_counts
# Out:
# Summer    166706
# Winter     39459
# Name: Season, dtype: int64

# %%
fig = plt.pie(Season_counts, labels=Season_counts.index, autopct='%.2f')

# %%
# The summer games have more participants as compared to the games held in winter.
